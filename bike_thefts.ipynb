# %%
# Dependencies and Setup
import pandas as pd

# %%
# Ottawa bike thefts file to load 
o_theft_url = "Resources/ottawa_bike_theft.csv"

# Read file and store into Pandas data frame
o_theft_df = pd.read_csv(o_theft_url)
o_theft_df.head()
# Out:
#              X            Y  ID Ottawa__Police_Division  Ottawa_Police_Sector  \
# 0  363023.6811  5015825.440   1                    West                    16
# 1  362414.6759  5014626.428   2                    West                    16
# 2  363782.6879  5016896.451   3                    West                    16
# 3  361526.0460  5014725.228   4                    West                    16
# 4  362697.6789  5015449.436   5                    West                    16
#
#   Report_Date Incident_StartDate Incident_EndDate  Weekday Location_Type  ...  \
# 0    2-Aug-15           2-Aug-15         2-Aug-15        1           NaN  ...
# 1   24-Aug-15          23-Aug-15        24-Aug-15        1           NaN  ...
# 2   25-Aug-15          31-Jul-15         1-Aug-15        6           NaN  ...
# 3   19-Sep-15          18-Sep-15              NaN        6           NaN  ...
# 4   16-Nov-15          13-Nov-15        16-Nov-15        6       Schools  ...
#
#   Bicycle_Type Bicycle_Frame                     Bicycle_Colour  \
# 0      REGULAR        UNISEX                               Grey
# 1     MOUNTAIN         MEN'S                      Black, Orange
# 2          BMX         MEN'S                              White
# 3       HYBRID       WOMEN'S                          Dark Blue
# 4        RACER        UNISEX  Silver, Aluminum, Stainless Steel
#
#    Bicycle_Speed          X.1          Y.1 Census_Tract_Unique_ID  \
# 0            0.0  363023.6811  5015825.440             5050140.07
# 1           21.0  362414.6759  5014626.428             5050140.04
# 2            1.0  363782.6879  5016896.451             5050140.03
# 3           18.0  361526.0460  5014725.228             5050141.15
# 4           10.0  362697.6789  5015449.436             5050140.07
#
#   Census_Tract_Name Object_ID  OBJECTID
# 0            140.07         1         0
# 1            140.04         2         1
# 2            140.03         3         2
# 3            141.15         4         3
# 4            140.07         5         4
#
# [5 rows x 26 columns]

# %%
# Vancouver bike thefts file to load 
v_theft_url = "Resources/vanc_bike_theft.csv"

# Read file and store into Pandas data frame
v_theft_df = pd.read_csv(v_theft_url)
v_theft_df.head()
# Out:
#                          TYPE  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0  Break and Enter Commercial  2012     12   14     8      52
# 1  Break and Enter Commercial  2019      3    7     2       6
# 2  Break and Enter Commercial  2019      8   27     4      12
# 3  Break and Enter Commercial  2021      4   26     4      44
# 4  Break and Enter Commercial  2014      8    8     5      13
#
#      HUNDRED_BLOCK NEIGHBOURHOOD            X             Y
# 0              NaN      Oakridge  491285.0000  5.453433e+06
# 1    10XX SITKA SQ      Fairview  490612.9648  5.457110e+06
# 2  10XX ALBERNI ST      West End  491007.7798  5.459174e+06
# 3  10XX ALBERNI ST      West End  491007.7798  5.459174e+06
# 4  10XX ALBERNI ST      West End  491015.9434  5.459166e+06
